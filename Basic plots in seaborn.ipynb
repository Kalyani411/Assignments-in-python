# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
example_data=pd.read_csv('C:/Users//KALYANI//Desktop//COURSE/salary.csv')
example_data
# Out:
#        Unnamed: 0   District    Salary  Age        English  \
# 0               0   Brooklyn  120000.0   31  Only language
# 1               1   Brooklyn   45000.0   28  Only language
# 2               2  Manhatten   85000.0   54  Only language
# 3               3  Manhatten   12000.0   45  Only language
# 4               4   Brooklyn       0.0   75      Very well
# ...           ...        ...       ...  ...            ...
# 59432       59432   Brooklyn       0.0   35      Very well
# 59433       59433     Queens       0.0   89  Only language
# 59434       59434      Bronx       0.0   34  Only language
# 59435       59435  Manhatten       0.0   61  Only language
# 59436       59436      Bronx   21000.0   25  Only language
#
#                  Education  Gender
# 0          Academic degree    Male
# 1          Academic degree  Female
# 2          Academic degree    Male
# 3      High school diploma  Female
# 4          Academic degree  Female
# ...                    ...     ...
# ...

# %%
sns.set(style="whitegrid")
sns.barplot(x="Education", y="Salary", hue="District",data=example_data)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Salary'>

# %%
sns.barplot(x="Education", y="Salary",data=example_data)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Salary'>

# %%
hist=np.random.normal(size=50)
sns.distplot(hist)
# Out:
# C:\Users\KALYANI\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(hist,shade=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
example_data=pd.read_csv('C:/Users//KALYANI//Desktop//COURSE/salary.csv')
example_data
sns.set(style="white")
sns.jointplot(x="Salary",y="Age",data=example_data)

# %%
sns.jointplot(x="Salary",y="Age",data=example_data,kind='kde',xlim=(0,500000),ylim=(0,100))

# %%
my_data=pd.read_csv('C:/Users//KALYANI//Desktop//COURSE/basic_details.csv')
my_data
# Out:
#    Height  Weight  Age Groups
# 0     150      76   25      A
# 1     143      64   27      A
# 2     123      86   28      A
# 3     165      35   43      B
# 4     176      86   63      B
# 5     189      47   21      B
# 6     194      76   56      C
# 7     142      46   67      C
# 8     134      87   39      C
# 9     146      46   48      C

# %%
sns.set(style="ticks",color_codes=True)
g=sns.pairplot(my_data,hue="Groups")

# %%
example_1_data=pd.read_csv('C:/Users//KALYANI//Desktop//COURSE/movie_scores.csv')
example_1_data
# Out:
#    Unnamed: 0                         MovieTitle  Tomatometer  AudienceScore
# 0           0                 The Shape of Water           91             73
# 1           1                      Black Panther           97             79
# 2           2                            Dunkirk           92             81
# 3           3                        The Martian           91             91
# 4           4  The Hobbit: An Unexpected Journey           64             83
